# %%
# Load the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load in the data
episodes = pd.read_csv(r"C:\Users\Dell\Downloads\friends_episodes.csv")
imdb = pd.read_csv(r"C:\Users\Dell\Downloads\friends_imdb.csv")

# %%
# View the first 5 rows of the `episodes` dataframe
episodes.head()
# Out:
#    season  episode_num_in_season  episode_num_overall  \
# 0       1                      1                    1
# 1       1                      2                    2
# 2       1                      3                    3
# 3       1                      4                    4
# 4       1                      5                    5
#
#                                             title    directed_by  \
# 0            The One Where Monica Gets a Roommate  James Burrows
# 1            The One with the Sonogram at the End  James Burrows
# 2                          The One with the Thumb  James Burrows
# 3              The One with George Stephanopoulos  James Burrows
# 4  The One with the East German Laundry Detergent  Pamela Fryman
#
#                        written_by original_air_date prod_code  us_viewers
# 0    David Crane & Marta Kauffman        1994-09-22    456650  21500000.0
# 1    David Crane & Marta Kauffman        1994-09-29    456652  20200000.0
# 2  Jeffrey Astrof & Mike Sikowitz        1994-10-06    456651  19500000.0
# 3                     Alexa Junge        1994-10-13    456654  19700000.0
# 4  Jeff Greenstein & Jeff Strauss        1994-10-20    456653  18600000.0

# %%
# View the first 5 rows of the `imdb` dataframe
imdb.head()
# Out:
#    season  episode_num                                           title  \
# 0       1            1            The One Where Monica Gets a Roommate
# 1       1            2            The One with the Sonogram at the End
# 2       1            3                          The One with the Thumb
# 3       1            4              The One with George Stephanopoulos
# 4       1            5  The One with the East German Laundry Detergent
#
#   original_air_date  imdb_rating  total_votes  \
# 0      22 Sep. 1994          8.3         8378
# 1      29 Sep. 1994          8.0         6441
# 2       6 Oct. 1994          8.1         6060
# 3      13 Oct. 1994          8.1         5892
# 4      20 Oct. 1994          8.4         5872
#
#                                                 desc
# 0  Monica and the gang introduce Rachel to the "r...
# 1  Ross finds out his ex-wife is pregnant. Rachel...
# 2  Monica becomes irritated when everyone likes h...
# 3  Joey and Chandler take Ross to a hockey game t...
# 4  Eager to spend time with Rachel, Ross pretends...

# %%
# Print out the number of rows in each dataframe
print('episodes: {}'.format(len(episodes.index)))
print('imdb: {}'.format(len(imdb.index)))
# Out:
# episodes: 236
# imdb: 235

# %%
# Count the number of episodes in each season in the `episodes` dataframe, then sort by the season
print('Episodes\n {}'.format(episodes.value_counts('season').sort_index()))

print('')
# Count the number of episodes in each season in the `imdb` dataframe, then sort by the season
print('IMDB\n {}'.format(imdb.value_counts('season').sort_index()))
# Out:
# Episodes
#  season
# 1     24
# 2     24
# 3     25
# 4     24
# 5     24
# 6     25
# 7     24
# 8     24
# 9     24
# 10    18
# dtype: int64
#
# IMDB
#  season
# 1     24
# 2     24
# 3     25
# 4     24
# 5     24
# 6     25
# 7     24
# 8     24
# 9     24
# 10    17
# dtype: int64

# %%
# Print all rows for season 10 in the episodes dataframe
episodes[episodes['season']==10].head(20)
# Out:
#      season  episode_num_in_season  episode_num_overall  \
# 218      10                      1                  219
# 219      10                      2                  220
# 220      10                      3                  221
# 221      10                      4                  222
# 222      10                      5                  223
# 223      10                      6                  224
# 224      10                      7                  225
# 225      10                      8                  226
# 226      10                      9                  227
# 227      10                     10                  228
# 228      10                     11                  229
# 229      10                     12                  230
# 230      10                     13                  231
# 231      10                     14                  232
# 232      10                     15                  233
# 233      10                     16                  234
# 234      10                     17                  235
# 235      10                     18                  236
#
#                                       title         directed_by  \
# 218      The One After Joey and Rachel Kiss     Kevin S. Bright
# 219              The One Where Ross Is Fine           Ben Weiss
# 220                 The One with Ross's Tan      Gary Halvorson
# 221                   The One with the Cake      Gary Halvorson
# 222  The One Where Rachel's Sister Babysits  Roger Christiansen
# 223                The One with Ross' Grant           Ben Weiss
# 224             The One with the Home Study     Kevin S. Bright
# 225      The One with the Late Thanksgiving      Gary Halvorson
# 226           The One with the Birth Mother     David Schwimmer
# 227      The One Where Chandler Gets Caught      Gary Halvorson
# 228        The One Where the Stripper Cries     Kevin S. Bright
# 229           The One with Phoebe's Wedding     Kevin S. Bright
# 230        The One Where Joey Speaks French      Gary Halvorson
# 231          The One with Princess Consuela      Gary Halvorson
# 232              The One Where Estelle Dies      Gary Halvorson
# 233  The One with Rachel's Going Away Party      Gary Halvorson
# 234                            The Last One     Kevin S. Bright
# 235                            The Last One     Kevin S. Bright
#
#                                             written_by original_air_date  \
# 218                           Andrew Reich & Ted Cohen        2003-09-25
# 219              Sherry Bilsing-Graham & Ellen Plummer        2003-10-02
# 220                                      Brian Buckner        2003-10-09
# 221                                     Robert Carlock        2003-10-23
# 222                                  Dana Klein Borkow        2003-10-30
# 223                                    Sebastian Jones        2003-11-06
# 224                                       Mark Kunerth        2003-11-13
# 225                              Shana Goldberg-Meehan        2003-11-20
# 226                                      Scott Silveri        2004-01-08
# 227                                        Doty Abrams        2004-01-15
# 228                       David Crane & Marta Kauffman        2004-02-05
# 229                 Robert Carlock & Dana Klein Borkow        2004-02-12
# 230              Sherry Bilsing-Graham & Ellen Plummer        2004-02-19
# 231  Story by: Robert CarlockTeleplay by: Tracy Reilly        2004-02-26
# 232  Story by: Mark KunerthTeleplay by: David Crane...        2004-04-22
# 233                           Andrew Reich & Ted Cohen        2004-04-29
# 234                       Marta Kauffman & David Crane        2004-05-06
# 235                       Marta Kauffman & David Crane        2004-05-06
#
#     prod_code  us_viewers
# 218    176251  24540000.0
# 219    176252  22370000.0
# 220    176253  21870000.0
# 221    176254  18760000.0
# 222    176255  19370000.0
# 223    176256  20370000.0
# 224    176257  20210000.0
# 225    176259  20660000.0
# 226    176258  25480000.0
# 227    176268  26680000.0
# 228    176260  24910000.0
# 229    176262  25900000.0
# 230    176261  24270000.0
# 231    176263  22820000.0
# 232    176264  22640000.0
# 233    176265  24510000.0
# 234    176266  52460000.0
# 235    176267  52460000.0

# %%
# Remove episode 236 from the episodes dataframe, then print out the last 5 episodes in season 10 as well as the number of rows in the dataframe to verify that it worked
episodes = episodes[episodes['episode_num_overall'] != 236]

print('episodes: {}'.format(len(episodes.index)))
episodes[episodes['season']==10].tail()
# Out:
# episodes: 235
#      season  episode_num_in_season  episode_num_overall  \
# 230      10                     13                  231
# 231      10                     14                  232
# 232      10                     15                  233
# 233      10                     16                  234
# 234      10                     17                  235
#
#                                       title      directed_by  \
# 230        The One Where Joey Speaks French   Gary Halvorson
# 231          The One with Princess Consuela   Gary Halvorson
# 232              The One Where Estelle Dies   Gary Halvorson
# 233  The One with Rachel's Going Away Party   Gary Halvorson
# 234                            The Last One  Kevin S. Bright
#
#                                             written_by original_air_date  \
# 230              Sherry Bilsing-Graham & Ellen Plummer        2004-02-19
# 231  Story by: Robert CarlockTeleplay by: Tracy Reilly        2004-02-26
# 232  Story by: Mark KunerthTeleplay by: David Crane...        2004-04-22
# 233                           Andrew Reich & Ted Cohen        2004-04-29
# 234                       Marta Kauffman & David Crane        2004-05-06
#
#     prod_code  us_viewers
# 230    176261  24270000.0
# 231    176263  22820000.0
# 232    176264  22640000.0
# 233    176265  24510000.0
# 234    176266  52460000.0

# %%
# Merge the two dataframes
df = pd.merge(episodes, imdb, how = 'left', left_on=['season', 'episode_num_in_season'], right_on=['season', 'episode_num'])

# Remove columns that we don't need
df.drop(['episode_num_in_season', 'title_x', 'episode_num_overall', 'title_y', 'prod_code', 'original_air_date_y'], axis=1, inplace=True)

# Clean up the column names
df.rename(columns={'original_air_date_x':'air_date'},inplace=True)

# Order the columns.  I like to do this because it is easier to interpret the data when looking at print outs of the first few rows
df = df[['season', 'episode_num', 'directed_by', 'written_by', 'air_date', 'us_viewers', 'imdb_rating', 'total_votes', 'desc']]

# Print the first 5 rows to make sure that the merge worked and that all the information is in df
df.head()
# Out:
#    season  episode_num    directed_by                      written_by  \
# 0       1            1  James Burrows    David Crane & Marta Kauffman
# 1       1            2  James Burrows    David Crane & Marta Kauffman
# 2       1            3  James Burrows  Jeffrey Astrof & Mike Sikowitz
# 3       1            4  James Burrows                     Alexa Junge
# 4       1            5  Pamela Fryman  Jeff Greenstein & Jeff Strauss
#
#      air_date  us_viewers  imdb_rating  total_votes  \
# 0  1994-09-22  21500000.0          8.3         8378
# 1  1994-09-29  20200000.0          8.0         6441
# 2  1994-10-06  19500000.0          8.1         6060
# 3  1994-10-13  19700000.0          8.1         5892
# 4  1994-10-20  18600000.0          8.4         5872
#
#                                                 desc
# 0  Monica and the gang introduce Rachel to the "r...
# 1  Ross finds out his ex-wife is pregnant. Rachel...
# 2  Monica becomes irritated when everyone likes h...
# 3  Joey and Chandler take Ross to a hockey game t...
# 4  Eager to spend time with Rachel, Ross pretends...

# %%
# Create a list of all the main characters
characters = ['Monica', 'Rachel', 'Phoebe', 'Ross', 'Joey', 'Chandler']

# Using a loop, create a column for each character.  1 indicates the character is mentioned in the decription, 0 indicates they are not mentioned
for i in characters:
    df[i] = df['desc'].str.contains(i, case=False).astype(int)
    
# Remove the desc column, as it is no longer necessary
df.drop('desc', axis=1, inplace= True)

# Print first 5 rows to make sure we got what we wanted
df.head()
# Out:
#    season  episode_num    directed_by                      written_by  \
# 0       1            1  James Burrows    David Crane & Marta Kauffman
# 1       1            2  James Burrows    David Crane & Marta Kauffman
# 2       1            3  James Burrows  Jeffrey Astrof & Mike Sikowitz
# 3       1            4  James Burrows                     Alexa Junge
# 4       1            5  Pamela Fryman  Jeff Greenstein & Jeff Strauss
#
#      air_date  us_viewers  imdb_rating  total_votes  Monica  Rachel  Phoebe  \
# 0  1994-09-22  21500000.0          8.3         8378       1       1       0
# 1  1994-09-29  20200000.0          8.0         6441       1       1       0
# 2  1994-10-06  19500000.0          8.1         6060       1       0       1
# 3  1994-10-13  19700000.0          8.1         5892       0       0       0
# 4  1994-10-20  18600000.0          8.4         5872       1       1       0
#
#    Ross  Joey  Chandler
# 0     0     0         0
# 1     1     0         0
# 2     0     0         1
# 3     1     1         1
# 4     1     1         1

# %%
# Create a new dataframe for character importance
char_importance = pd.melt(df, id_vars=['season', 'us_viewers', 'imdb_rating'], value_vars=characters, var_name='character', value_name='in_episode')

# Filtered `char_importance` to episodes that the characters appears in
char_importance = char_importance[char_importance['in_episode'] == 1]
char_importance.head()
# Out:
#    season  us_viewers  imdb_rating character  in_episode
# 0       1  21500000.0          8.3    Monica           1
# 1       1  20200000.0          8.0    Monica           1
# 2       1  19500000.0          8.1    Monica           1
# 4       1  18600000.0          8.4    Monica           1
# 5       1  18200000.0          8.1    Monica           1

# %%
# Create Plot
plt.figure(figsize=(10,5)) 
sns.countplot(data=char_importance, y='character')
plt.suptitle('\'Friends\' Characters Importance', y = 1, fontsize=15)
plt.title('*Based on Appearance in Episode Description', y=.999, fontsize=10)
# Out:
# Text(0.5, 0.999, '*Based on Appearance in Episode Description')

# %%
# Create plot
plt.figure(figsize=(15,10)) 
sns.countplot(data=char_importance, y='season', hue='character')
plt.suptitle('\'Friends\' Characters Importance By Season', y = 1, fontsize=15)
plt.title('*Based on Appearance in Episode Description', y=1.09, fontsize=10)
plt.xlabel('Appearances')
plt.ylabel('Season')
plt.legend(title= 'Characters')

# %%
# Create Average Views for each Character overall 
avg_char_views = char_importance[['character', 'imdb_rating']].groupby(['character']).mean().reset_index()

# Plot 
plt.figure(figsize=(10,10)) 
sns.barplot(x='imdb_rating', y='character', data=avg_char_views.sort_values('imdb_rating', ascending=False))
plt.suptitle('\'Friends\' Character Average IMDB Rating', fontsize=20)
plt.title('Entire Series - Based on IMDB Ratings of Episodes About Character', y=1.05, fontsize=10)
plt.xlabel('Average IMDB Rating')
plt.ylabel('Character')
plt.xlim([8.3, 8.5])
# Out:
# (8.3, 8.5)

# %%
# Prep data to be plotted
df['us_viewers'] = df['us_viewers'].astype(int)
df['written_by'] = df['written_by'].str.split('Teleplay', expand=True)[0]
df['written_by'] = df['written_by'].str.replace('Story by: ', '')

# writers dataframe. Group by the writers across entire series
writers_df = df[['written_by', 'us_viewers','imdb_rating']].groupby(['written_by']).mean().reset_index()

# How many episodes were done by each writing group
plt.figure(figsize=(15,12)) 
sns.countplot(data=df, y='written_by', order = df['written_by'].value_counts().index)
plt.suptitle('How Many Episodes of \'Friends\' Were Done by Each Writer? ', y = 1, fontsize=15)
plt.xlabel('Episodes')
plt.ylabel('Writing Team')
# Out:
# Text(0, 0.5, 'Writing Team')

# %%
# Plotting for each season individually, because one plot for all of them is unclear and difficult to read.
for i in df['season'].unique():
    plt.figure(figsize=(10,5)) 
    temp = df[df['season']==i]
    sns.countplot(data=temp, y='written_by', order = temp['written_by'].value_counts().index)
    plt.suptitle('How Many Episodes of \'Friends\' Were Done by Each Writer in Season {}?'.format(i), fontsize=15)
    plt.xlabel('Episodes')
    plt.ylabel('Writing Teams')

# %%
# Create Plot
plt.figure(figsize=(15,12)) 
sns.barplot(x='us_viewers', y='written_by', data=writers_df.sort_values('us_viewers', ascending=False))
plt.suptitle('\'Friends\' Writer Team Average Number of Views per Episode', fontsize=20)
plt.title('Entire Series', y=1.05, fontsize=10)
plt.xlabel('Average Viewers per Episode \n(In Millions)')
plt.ylabel('Writers')
# Out:
# Text(0, 0.5, 'Writers')

# %%
# Create Plot
plt.figure(figsize=(10,7)) 
sns.countplot(data=df, y = 'directed_by', order = df['directed_by'].value_counts().index)
plt.suptitle('How many Episodes of \'Friends\' Was Each Directing Team Responsible For?', y = 1, fontsize=15)
# Out:
# Text(0.5, 1, "How many Episodes of 'Friends' Was Each Directing Team Responsible For?")

# %%
# writers dataframe. Group by the writers across entire series
directed_df = df[['directed_by', 'us_viewers','imdb_rating']].groupby(['directed_by']).mean().reset_index()

# plot
plt.figure(figsize=(15,12)) 
sns.barplot(x='imdb_rating', y='directed_by', data=directed_df.sort_values('imdb_rating', ascending=False))
plt.suptitle('\'Friends\' Each Directing Team\'s Average IMDB Rating Overall', fontsize=20)
plt.title('Entire Series', y=1.05, fontsize=10)
plt.xlabel('Average IMDB Rating')
plt.ylabel('Writers')
# Out:
# Text(0, 0.5, 'Writers')

# %%
# Create plots
for i in df['season'].unique():
    plt.figure(figsize=(10,5)) 
    temp = df[df['season']==i]
    sns.countplot(data=temp, y='directed_by', order = temp['directed_by'].value_counts().index)
    plt.suptitle('How Many Episodes of \'Friends\' Were Done by Each Directing Team in Season {}?'.format(i), fontsize=15)
    plt.xlabel('Episodes')
    plt.ylabel('Directing Team')
